# %%
df1=spark.sql("SELECT * FROM `hive_metastore`.`default`.`str_report`") 
df1.show()
# Out:
# +-------+--------------------+----------+----------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
# |Census#|          Hotel Name|    DateTY|    DateLY|PropSupTY|PropDemTY|PropRevTY|PropSupLY|PropDemLY|PropRevLY|CompSupTY|CompDemTY|CompRevTY|CompSupLY|CompDemLY|CompRevLY|
# +-------+--------------------+----------+----------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
# |   3071|Courtyard Dover E...|2022-01-09|2021-01-10|      240|      169|    14907|      240|       85|     5449|     1149|      470|    51647|     1149|      330|    27098|
# |   3071|Courtyard Dover E...|2022-01-10|2021-01-11|      240|      153|    14705|      240|       68|     4689|     1149|      440|    48694|     1149|      333|    28891|
# ...

# %%
from pyspark.sql.functions import col,to_date,date_format
import pyspark.sql.functions as f

df1 = df1.withColumn("ProOCC_TY",col("PropDemTY")/col("PropSupTY"))
df1 = df1.withColumn("ProADR_TY",col("PropRevTY")/col("PropDemTY"))
df1 = df1.withColumn("ProRevPAR_TY",col("PropRevTY")/col("PropSupTY"))
# df1 = df1.withColumn("DateTY", to_date("DateTY", "dd/MM/yyyy"))
# df1 = df1.withColumn("DateLY", to_date("DateLY", "dd/MM/yyyy"))

# %%
df1 = df1.withColumn("ProOCC_LY",col("PropDemLY")/col("PropSupLY"))
df1 = df1.withColumn("ProADR_LY",col("PropRevLY")/col("PropDemLY"))
df1 = df1.withColumn("ProRevPAR_LY",col("PropRevLY")/col("PropSupLY"))

# %%
df1 = df1.withColumn("CompOCC_TY",col("CompDemTY")/col("CompSupTY"))
df1 = df1.withColumn("CompADR_TY",col("CompRevTY")/col("CompDemTY"))
df1 = df1.withColumn("CompRevPAR_TY",col("CompRevTY")/col("CompSupTY"))

# %%
df1 = df1.withColumn("CompOCC_LY",col("CompDemLY")/col("CompSupLY"))
df1 = df1.withColumn("CompADR_LY",col("CompRevLY")/col("CompDemLY"))
df1 = df1.withColumn("CompRevPAR_LY",col("CompRevLY")/col("CompSupLY"))

# %%
df1
# Out:
# DataFrame[Census#: bigint, Hotel Name: string, DateTY: date, DateLY: date, PropSupTY: bigint, PropDemTY: bigint, PropRevTY: bigint, PropSupLY: bigint, PropDemLY: bigint, PropRevLY: bigint, CompSupTY: bigint, CompDemTY: bigint, CompRevTY: bigint, CompSupLY: bigint, CompDemLY: bigint, CompRevLY: bigint, ProOCC_TY: double, ProADR_TY: double, ProRevPAR_TY: double, ProOCC_LY: double, ProADR_LY: double, ProRevPAR_LY: double, CompOCC_TY: double, CompADR_TY: double, CompRevPAR_TY: double, CompOCC_LY: double, CompADR_LY: double, CompRevPAR_LY: double]

# %%
df1.show()
# Out:
# +-------+--------------------+----------+----------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+------------------+------------------+------------------+-------------------+-----------------+------------------+-------------------+------------------+------------------+-------------------+-----------------+------------------+
# |Census#|          Hotel Name|    DateTY|    DateLY|PropSupTY|PropDemTY|PropRevTY|PropSupLY|PropDemLY|PropRevLY|CompSupTY|CompDemTY|CompRevTY|CompSupLY|CompDemLY|CompRevLY|         ProOCC_TY|         ProADR_TY|      ProRevPAR_TY|          ProOCC_LY|        ProADR_LY|      ProRevPAR_LY|         CompOCC_TY|        CompADR_TY|     CompRevPAR_TY|         CompOCC_LY|       CompADR_LY|     CompRevPAR_LY|
# ...

# %%
# import pandas as pd
# df2 = df1.toPandas()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-1373997221325585>, line 2
#       1 import pandas as pd
# ----> 2 df2 = df1.toPandas()
#
# NameError: name 'df1' is not defined

# %%
df1.write.format("delta").option("delta.columnMapping.mode", "name").saveAsTable("OCC11")
